# %% [markdown]
# ## WEBSCRAPING WATCH PRODUCTS IN PYTHON USING BEAUTIFULSOUP

# %% [markdown]
# #### Import libraries we will utilise

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import requests

# %%
# URL
url = 'https://www.misterchrono.com/en/126-watch-bookstore'

# %%
# Get my user agent
Header = ({
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
    'Accept-language':'en-US, en;q=0.5'
})

# %%
# HTTPS REQUEST
page = requests.get(url, headers=Header)

# %%
type(page.content)
# Out:
# bytes

# %%
#To convert into HTML Format
soup = bs(page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-us"><![endif]-->
# <!--[if IE 7]><html class="no-js lt-ie9 lt-ie8 ie7" lang="en-us"><![endif]-->
# <!--[if IE 8]><html class="no-js lt-ie9 ie8" lang="en-us"><![endif]-->
# <!--[if gt IE 8]> <html class="no-js ie9" lang="en-us"><![endif]-->
# <html class="default" lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <title>Watch Bookstore - MisterChrono</title>
# <meta content="Watch Bookstore" name="description"/>
# <meta content="watch, book" name="keywords"/>
# <meta content="PrestaShop" name="generator"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="width=device-width, minimum-scale=0.25, maximum-scale=1.6, initial-scale=1.0" name="viewport"/> <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link href="/img/favicon.ico?1697125177" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/img/favicon.ico?1697125177" rel="shortcut icon" type="image/x-icon"/>
# <link href="/themes/leo_mayshop/css/global.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/fancybox/jquery.fancybox.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/product_list.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/category.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/scenes.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcurrencies/blockcurrencies.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocklanguages/blocklanguages.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.core.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.slider.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocklayered/blocklayered.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcontact/blockcontact.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocksearch/blocksearch.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/autocomplete/jquery.autocomplete.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocktopmenu/css/blocktopmenu.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocktopmenu/css/superfish-modified.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/themeconfigurator/css/hooks.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockgrouptop/blockgrouptop.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoblog/assets/leoblog.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leomenusidebar/leomenusidebar.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/typo/typo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/iView/iview.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/iView/skin_4_responsive/style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/ApImageHotspot.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/ApImage360.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/animate.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/owl.carousel.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/owl.theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/styles.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leobootstrapmenu/megamenu.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockuserinfo/blockuserinfo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/productcomments/productcomments.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcart/blockcart.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/bxslider/jquery.bxslider.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockwishlist/blockwishlist.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/ets_advancedcaptcha/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/responsive.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/productcomposer/views/css/front/pc_cart.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/productcomposer/views/css/front/six.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var CUSTOMIZE_TEXTFIELD = 1;
# var FancyboxI18nClose = 'Close';
# var FancyboxI18nNext = 'Next';
# var FancyboxI18nPrev = 'Previous';
# var added_to_wishlist = 'The product was successfully added to your wishlist.';
# var ajax_allowed = true;
# var ajaxsearch = true;
# var baseDir = 'https://www.misterchrono.com/';
# var baseUri = 'https://www.misterchrono.com/';
# var blocklayeredSliderName = {"price":"price","weight":"weight"};
# var blocksearch_type = 'top';
# var blockwishlist_add = 'The product was successfully added to your wishlist';
# var blockwishlist_remove = 'The product was successfully removed from your wishlist';
# var blockwishlist_viewwishlist = 'View your wishlist';
# var comparator_max_item = 0;
# var comparedProductsIds = [];
# var contentOnly = false;
# var currency = {"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac","blank":"1","conversion_rate":"1.000000","deleted":"0","format":"2","decimals":"1","active":"1","prefix":"","suffix":" \u20ac","id_shop_list":null,"force_id":false};
# var currencyBlank = 1;
# var currencyFormat = 2;
# var currencyRate = 1;
# var currencySign = '€';
# var customizationIdMessage = 'Customization #';
# var delete_txt = 'Delete';
# var displayList = false;
# var filters = [{"type_lite":"quantity","type":"quantity","id_key":0,"name":"Availability","values":[{"name":"Not available","nbr":1,"link":"https:\/\/www.misterchrono.com\/en\/126-watch-bookstore#availability-not_available","rel":"nofollow"},{"name":"In stock","nbr":35,"link":"https:\/\/www.misterchrono.com\/en\/126-watch-bookstore#availability-in_stock","rel":"nofollow"}],"filter_show_limit":"0","filter_type":"0"},{"type_lite":"id_feature","type":"id_feature","id_key":10,"values":{"124":{"nbr":12,"name":"English","url_name":"","meta_title":"","link":"https:\/\/www.misterchrono.com\/en\/126-watch-bookstore#language-english","rel":"nofollow"},"123":{"nbr":15,"name":"French","url_name":"","meta_title":"","link":"https:\/\/www.misterchrono.com\/en\/126-watch-bookstore#language-french","rel":"nofollow"}},"name":"Language","url_name":"language","meta_title":"","filter_show_limit":"0","filter_type":"0"}];
# var freeProductTranslation = 'Free!';
# var freeShippingTranslation = 'Free shipping!';
# var generated_date = 1708812990;
# var hasDeliveryAddress = false;
# var highDPI = false;
# var id_lang = 1;
# var img_dir = 'https://www.misterchrono.com/themes/leo_mayshop/img/';
# var instantsearch = true;
# var isGuest = 0;
# var isLogged = 0;
# var isMobile = false;
# var isPsVersion17 = false;
# var is_seven = false;
# var loggin_required = 'You must be logged in to manage your wishlist.';
# var max_item = 'You cannot add more than 0 product(s) to the product comparison';
# var min_item = 'Please select at least one product';
# var mywishlist_url = 'https://www.misterchrono.com/en/module/blockwishlist/mywishlist';
# var nbr_images = '25';
# var page_name = 'category';
# var param_product_url = '#';
# var pc_config = {"id_product":0,"id_layout":1,"columns":2,"active":false,"required":false,"popup":0,"manage_quantity":false,"title":null,"primary_color":"#B1E4F9","secondary_color":"#F8E955","invert_groups":false,"allow_upload":false,"allow_text":false,"text_on_top":false,"display_picker":false,"max_upload":0,"upload_cost":0,"total_upload_cost":0,"empty":false,"bg":false,"bgThumb":false,"mask":false,"maskThumb":false,"id":null,"id_shop_list":null,"force_id":false};
# var pc_icon_height = 150;
# var pc_link = 'https://www.misterchrono.com/en/module/productcomposer/default';
# var pc_link_selection = 'https://www.misterchrono.com/en/module/productcomposer/selection';
# var pc_link_text = 'https://www.misterchrono.com/en/module/productcomposer/text';
# var pc_module_dir = 'https://www.misterchrono.com/modules/productcomposer/';
# var pc_special = 3486;
# var pc_tax = 0;
# var pc_version = '1.8.6';
# var priceDisplayMethod = 0;
# var priceDisplayPrecision = 2;
# var productcompare_add = 'The product has been added to list compare';
# var productcompare_remove = 'The product was successfully removed from list compare';
# var productcompare_url = 'https://www.misterchrono.com/en/comparaison-produits';
# var productcompare_viewlistcompare = 'View list compare';
# var ps_module_dev = false;
# var pslookbook_url = 'https://www.misterchrono.com/en/module/pslookbook/FrontImageDisplay';
# var quickView = true;
# var removingLinkText = 'remove this product from my cart';
# var request = 'https://www.misterchrono.com/en/126-watch-bookstore';
# var roundMode = 2;
# var search_url = 'https://www.misterchrono.com/en/recherche';
# var static_token = '2649f232fa66a36820c757455e61e85e';
# var toBeDetermined = 'To be determined';
# var token = '4531b0a0cc4b89c7bb0ccdf0c0616685';
# var url_upload = 'https://www.misterchrono.com/modules/pslookbook/upload/';
# var usingSecureMode = true;
# var wishlistProductsIds = false;
# </script>
# <script src="/js/jquery/jquery-1.11.0.min.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.easing.js" type="text/javascript"></script>
# <script src="/js/tools.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/global.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/10-bootstrap.min.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/15-jquery.total-storage.min.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/15-jquery.uniform-modified.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/fancybox/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/category.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocklayered/blocklayered.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.core.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.widget.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.mouse.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.slider.min.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.scrollTo.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/autocomplete/jquery.autocomplete.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocksearch/blocksearch.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/hoverIntent.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/superfish-modified.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/blocktopmenu.js" type="text/javascript"></script>
# <script src="/modules/leoslideshow/views/js/iView/raphael-min.js" type="text/javascript"></script>
# <script src="/modules/leoslideshow/views/js/iView/iview.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/ApImageHotspot.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/ApImage360.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/waypoints.min.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/jquery.stellar.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/owl.carousel.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/countdown.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/script.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blockcart/ajax-cart.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.serialScroll.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/bxslider/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blockwishlist/js/ajax-wishlist.js" type="text/javascript"></script>
# <script src="/modules/ets_advancedcaptcha/views/js/front.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/pc_tools.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/tn_compat.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/front/pc_cart.js" type="text/javascript"></script>
# <script src="/modules/lyoshowvatfree/views/js/product9.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var pc_message = {
#         error   : 'An error occurred',
#         confirm   : 'Are you sure you want to delete this item?',
#         required  : 'The group \"_group_\" is required. Please choose an option and retry',
#         required_field  : 'The field \"_field_\" is required. Please fill it',
#         required_design : 'Please design your product first'
#     };
# </script>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,600&amp;subset=latin,latin-ext" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Playfair+Display" rel="stylesheet" type="text/css"/>
# <!-- font-family: 'Playfair Display', serif; -->
# <!--[if IE 8]>
# 		<script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# 		<script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
# 		<![endif]-->
# </head>
# <body class="category category-126 category-watch-bookstore show-left-column hide-right-column lang_en fullwidth header-default" id="category">
# <section data-column="col-xs-12 col-sm-6 col-md-4" data-type="grid" id="page">
# <!-- Header -->
# <header class="header-center" id="header">
# <section class="header-container">
# <div class="header-left" id="header-main">
# <div id="header_content">
# <div class="inner">
# <div class="top">
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="header-top container">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-4 col-xs-6 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGeneral -->
# <div class="ApHtml block">
# <p>Phone: +33 (0)953420464 <span>- </span>WhatsApp:+33 686153329</p>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-center col-lg-4 col-md-4 col-sm-5 col-xs-6 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block currencies module -->
# <!-- /Block currencies module -->
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block user information module NAV  -->
# <div class="header_user_info popup-over e-translate-top tool-topbar">
# <div class="popup-title" data-toggle="dropdown"><span>Setting</span></div>
# <ul class="links popup-content">
# <li><a class="login" href="https://www.misterchrono.com/en/mon-compte" rel="nofollow" title="Login to your customer account">
# <i class="fa fa-unlock-alt"></i>Sign in
#    </a></li>
# <li>
# <a href="https://www.misterchrono.com/en/mon-compte" title="My account"><i class="fa fa-user"></i>My Account</a>
# </li>
# <li class="last"><a class="last" href="https://www.misterchrono.com/en/commande" title="Checkout"><i class="fa fa-share"></i>Checkout</a></li>
# <li class="first">
# <a href="https://www.misterchrono.com/en/module/blockwishlist/mywishlist" id="wishlist-total" title="My wishlists">
# <i class="fa fa-heart"></i>Wish List<span class="ap-total-wishlist ap-total"></span></a>
# </li>
# <li>
# <a href="https://www.misterchrono.com/en/comparaison-produits" rel="nofollow" title="Compare">
# <i class="fa fa-compress"></i>Compare<span class="ap-total-compare ap-total"></span>
# </a>
# </li>
# </ul>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block languages module -->
# <div class="popup-over e-scale">
# <div class="popup-title" data-toggle="dropdown"><a href="#" title="Languages">
# <span>English</span>
# </a>
# </div>
# <div class="popup-content">
# <div class="languages-block" id="languages-block-top">
# <ul class="languages-block_ul" id="first-languages">
# <li class="selected">
# <span><img alt="en" height="11" src="https://www.misterchrono.com/img/l/1.jpg" width="16"/> English</span>
# </li>
# <li>
# <a href="https://www.misterchrono.com/fr/126-librairie-horlogere" title="Français (French)">
# <span><img alt="fr" height="11" src="https://www.misterchrono.com/img/l/2.jpg" width="16"/> Français</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- /Block languages module -->
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-3 col-xs-12 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- MODULE Block cart -->
# <div class="blockcart_top clearfix pull-right">
# <div class="shopping_cart pull-right" id="cart">
# <a href="https://www.misterchrono.com/en/commande" rel="nofollow" title="View my shopping cart">
# <div class="cart-inner media-body pull-left">
# <h4>Cart</h4>
# </div>
# <div class="title-cart pull-left">
# <div class="cart-quantity">
# <span class="ajax_cart_quantity unvisible">0</span>
# <span class="ajax_cart_no_product">0</span>
# </div>
# </div>
# </a>
# <div class="cart_block block exclusive">
# <div class="block_content">
# <!-- block list of products -->
# <div class="cart_block_list">
# <p class="cart_block_no_products">
# 							No products
# 						</p>
# <div class="cart-prices">
# <div class="cart-prices-line first-line">
# <span class="price cart_block_shipping_cost ajax_cart_shipping_cost unvisible">
# 																			 To be determined																	</span>
# <span class="unvisible">
# 									Shipping
# 								</span>
# </div>
# <div class="cart-prices-line">
# <span class="price cart_block_tax_cost ajax_cart_tax_cost">0,00 €</span>
# <span>Tax</span>
# </div>
# <div class="cart-prices-line last-line">
# <span class="price cart_block_total ajax_block_cart_total">0,00 €</span>
# <span>Total</span>
# </div>
# <p>
# 																	Prices are tax included
# 																</p>
# </div>
# <p class="cart-buttons clearfix">
# <a class="btn btn-warning button-medium button button-small pull-right" href="https://www.misterchrono.com/en/commande" id="button_order_cart" rel="nofollow" title="Check out">
# <span>
# 									Check out
# 								</span>
# </a>
# </p>
# </div>
# </div>
# </div><!-- .cart_block -->
# </div>
# </div>
# <div id="layer_cart">
# <div class="clearfix">
# <div class="layer_cart_product col-xs-12 col-md-6">
# <span class="cross" title="Close window"></span>
# <span class="title">
# <i class="fa fa-ok"></i>Product successfully added to your shopping cart
# 				</span>
# <div class="product-image-container layer_cart_img">
# </div>
# <div class="layer_cart_product_info">
# <span class="product-name" id="layer_cart_product_title"></span>
# <span id="layer_cart_product_attributes"></span>
# <div>
# <strong class="dark">Quantity</strong>
# <span id="layer_cart_product_quantity"></span>
# </div>
# <div>
# <strong class="dark">Total</strong>
# <span id="layer_cart_product_price"></span>
# </div>
# </div>
# </div>
# <div class="layer_cart_cart col-xs-12 col-md-6">
# <span class="title">
# <!-- Plural Case [both cases are needed because page may be updated in Javascript] -->
# <span class="ajax_cart_product_txt_s unvisible">
# 						There are <span class="ajax_cart_quantity">0</span> items in your cart.
# 					</span>
# <!-- Singular Case [both cases are needed because page may be updated in Javascript] -->
# <span class="ajax_cart_product_txt">
# 						There is 1 item in your cart.
# 					</span>
# </span>
# <div class="layer_cart_row">
# <strong class="dark">
# 						Total products
# 																					(tax incl.)
# 																		</strong>
# <span class="ajax_block_products_total">
# </span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark unvisible">
# 						Total shipping (tax incl.)					</strong>
# <span class="ajax_cart_shipping_cost unvisible">
# 													 To be determined											</span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark">Tax</strong>
# <span class="price cart_block_tax_cost ajax_cart_tax_cost">0,00 €</span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark">
# 						Total
# 																					(tax incl.)
# 																		</strong>
# <span class="ajax_block_cart_total">
# </span>
# </div>
# <div class="button-container">
# <span class="continue btn btn-outline button exclusive-medium" title="Continue shopping">
# <span>
# 							Continue shopping
# 						</span>
# </span>
# <a class="btn btn-warning button pull-right" href="https://www.misterchrono.com/en/commande" rel="nofollow" title="Proceed to checkout">
# <span>
# 							Proceed to checkout
# 						</span>
# </a>
# </div>
# </div>
# </div>
# <div class="crossseling"></div>
# </div> <!-- #layer_cart -->
# <div class="layer_cart_overlay"></div>
# <!-- /MODULE Block cart -->
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block search module TOP -->
# <div class="popup-over pull-right e-translate-down" id="search_block_top">
# <span class="fa fa-search" title="Search"></span>
# <form action="//www.misterchrono.com/en/recherche" id="searchbox" method="get">
# <input name="controller" type="hidden" value="search"/>
# <input name="orderby" type="hidden" value="position"/>
# <input name="orderway" type="hidden" value="desc"/>
# <input class="search_query form-control" id="search_query_top" name="search_query" placeholder="Search" type="text" value=""/>
# <button class="btn btn-outline-inverse fa fa-search" name="submit_search" type="submit"> </button>
# </form>
# </div>
# <!-- /Block search module TOP -->
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="container">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGenCode -->
# <div id="header_logo"> <a href="https://www.misterchrono.com/" title="MisterChrono"> <img alt="MisterChrono" class="logo img-responsive" height="50" src="https://www.misterchrono.com/img/misterchrono-paris-logo-1566525515.jpg" width="401"/> </a> </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div class="clearfix" id="leo-megamenu">
# <nav class="sf-contener leo-megamenu" id="cavas_menu">
# <div role="navigation">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button class="navbar-toggle btn-outline-inverse" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="fa fa-bars"></span>
# </button>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse navbar-ex1-collapse" id="leo-top-menu">
# <ul class="nav navbar-nav megamenu"><li class="parent dropdown">
# <a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/index.php" target="_self"><span class="menu-title">Home</span><b class="caret"></b></a><div class="dropdown-sub dropdown-menu"><div class="dropdown-menu-inner"><div class="row"><div class="mega-col col-sm-12"> <div class="mega-col-inner"></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch straps</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/344-watch-straps" target="_self"><span class="menu-title">Ready to wear straps  </span></a></li><li class=""><a href="https://www.misterchrono.com/en/accessories-visibles/3485-camille-fournet-bespoke-product-3050348544220.html" target="_self"><span class="menu-title">Bespoke made straps</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch Maintenance</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/103-watchmaker-tools" target="_self"><span class="menu-title">Watch tools</span></a></li><li class=""><a href="https://www.misterchrono.com/en/content/30-watch-service" target="_self"><span class="menu-title">Our service center</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch Protection</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/144-safe" target="_self"><span class="menu-title">Safes for watches</span></a></li><li class=""><a href="https://www.misterchrono.com/en/96-watchwinders" target="_self"><span class="menu-title">Watchwinders</span></a></li><li class=""><a href="https://www.misterchrono.com/en/106-watch-boxes" target="_self"><span class="menu-title">Watch boxes</span></a></li><li class=""><a href="https://www.misterchrono.com/en/102-traveler-cases-for-watches" target="_self"><span class="menu-title">Watch travel cases</span></a></li><li class=""><a href="https://www.misterchrono.com/en/content/43-service-sur-mesure" target="_self"><span class="menu-title">Our customisation center</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Lifestyle</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/126-watch-bookstore" target="_self"><span class="menu-title">Bookstore</span></a></li><li class=""><a href="https://www.misterchrono.com/en/161-boutons-de-manchette" target="_self"><span class="menu-title">Cufflinks</span></a></li><li class=""><a href="https://www.misterchrono.com/en/228-belts-and-bracelets-" target="_self"><span class="menu-title">Belts and bracelets</span></a></li><li class=""><a href="https://www.misterchrono.com/en/232-clothes" target="_self"><span class="menu-tit ...
# <a class="has-category" href="https://www.misterchrono.com/en/227-sales" target="_self"><span class="menu-title">Sales</span></a></li><li class="">
# <a class="has-category" href="https://www.misterchrono.com/en/content/44-gallery" target="_self"><span class="menu-title">Gallery</span></a></li><li class="">
# <a class="has-category" href="https://www.misterchrono.com/en/blog.html" target="_self"><span class="menu-title">Blog</span></a></li></ul>
# </div>
# </div>
# </nav>
# </div>
# <script type="text/javascript">
# // <![CDATA[
# 	var current_link = "http://www.misterchrono.com/en/";
# 	//alert(request);
#     var currentURL = window.location;
#     currentURL = String(currentURL);
#     currentURL = currentURL.replace("https://","").replace("http://","").replace("www.","").replace( /#\w*/, "" );
#     current_link = current_link.replace("https://","").replace("http://","").replace("www.","");
#     isHomeMenu = 0;
#     if($("body").attr("id")=="index") isHomeMenu = 1;
#     $(".megamenu > li > a").each(function() {
#         menuURL = $(this).attr("href").replace("https://","").replace("http://","").replace("www.","").replace( /#\w*/, "" );
# 		if( (currentURL == menuURL) || (currentURL.replace(current_link,"") == menuURL) || isHomeMenu){
# 			$(this).parent().addClass("active");
#             return false;
# 		}
#     });
# // ]]>
# </script>
# <script type="text/javascript">
#     (function($) {
#         $.fn.OffCavasmenu = function(opts) {
#             // default configuration
#             var config = $.extend({}, {
#                 opt1: null,
#                 text_warning_select: "Please select One to remove?",
#                 text_confirm_remove: "Are you sure to remove footer row?",
#                 JSON: null
#             }, opts);
#             // main function
#             // initialize every element
#             this.each(function() {
#                 var $btn = $('#cavas_menu .navbar-toggle');
#                 var $nav = null;
#                 if (!$btn.length)
#                     return;
#                 var $nav = $('<section id="off-canvas-nav" class="leo-megamenu"><nav class="offcanvas-mainnav"><div id="off-canvas-button"><span class="off-canvas-nav"></span>Close</div></nav></section>');
#                 var $menucontent = $($btn.data('target')).find('.megamenu').clone();
#                 $("body").append($nav);
#                 $("#off-canvas-nav .offcanvas-mainnav").append($menucontent);
#                 $("#off-canvas-nav .offcanvas-mainnav").css('min-height',$(window).height()+30+"px");
#                 $("html").addClass ("off-canvas");
#                 $("#off-canvas-button").click( function(){
#                         $btn.click();
#                 } );
#                 $btn.toggle(function() {
#                     $("body").removeClass("off-canvas-inactive").addClass("off-canvas-active");
#                 }, function() {
#                     $("body").removeClass("off-canvas-active").addClass("off-canvas-inactive");
#                 });
#             });
#             return this;
#         }
#     })(jQuery);
#     $(document).ready(function() {
#         jQuery("#cavas_menu").OffCavasmenu();
#         $('#cavas_menu .navbar-toggle').click(function() {
#             $('body,html').animate({
#                 scrollTop: 0
#             }, 0);
# 			if ($('html').hasClass('fp-enabled')) {
# 				if ($('body').hasClass('off-canvas-active'))
# 				{
# 					$.fn.fullpage.pau();
# 				}
# 				else
# 				{
# 					$.fn.fullpage.con();
# 				};
# 			};
#             return false;
#         });
#     });
#     $(document.body).on('click', '[data-toggle="dropdown"]' ,function(){
#         if(!$(this).parent().hasClass('open') && this.href && this.href != '#'){
#             window.location.href = this.href;
#         }
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# <div id="pc_top">
# <div class="pc_cust" data-id="_">Customization:</div>
# <div class="pc_cart_container">
# <div class="pc_cart">
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# </section>
# </header>
# <div class="clearfix" id="breadcrumb">
# <div class="container">
# <!-- Breadcrumb -->
# <div class="breadcrumb clearfix aaa">
# <a class="home" href="https://www.misterchrono.com/" title="Return to Home">Home</a>
# <span &gt;="" class="navigation-pipe"></span>
# 					Watch Bookstore
# 			</div>
# <!-- /Breadcrumb -->
# </div>
# </div>
# <!-- Content -->
# <section class="columns-container" id="columns">
# <div class="container">
# <div class="row">
# <!-- Left -->
# <section class="column sidebar col-md-3" id="left_column">
# <div class="block" id="layered_block_left">
# <h4 class="title_block">Catalog</h4>
# <div class="block_content">
# <form action="#" id="layered_form">
# <div>
# <div id="enabled_filters">
# <span class="layered_subtitle" style="float: none;">
# 						Enabled filters:
# 					</span>
# <ul>
# </ul>
# </div>
# <div class="layered_filter">
# <div class="layered_subtitle_heading">
# <span class="layered_subtitle">Availability</span>
# <!--<span class="layered_close">
#                             	<a href="#" data-rel="ul_layered_quantity_0"></a>
#                             </span>-->
# </div>
# <ul class="col-lg-12 layered_filter_ul" id="ul_layered_quantity_0">
# <li class="nomargin hiddable col-lg-12">
# <input class="checkbox" id="layered_quantity_0" name="layered_quantity_0" type="checkbox" value="0"/>
# <label for="layered_quantity_0">
# <a data-rel="nofollow" href="https://www.misterchrono.com/en/126-watch-bookstore#availability-not_available">Not available<span> (1)</span></a>
# </label>
# </li>
# <li class="nomargin hiddable col-lg-12">
# <input class="checkbox" id="layered_quantity_1" name="layered_quantity_1" type="checkbox" value="1"/>
# <label for="layered_quantity_1">
# <a data-rel="nofollow" href="https://www.misterchrono.com/en/126-watch-bookstore#availability-in_stock">In stock<span> (35)</span></a>
# </label>
# </li>
# </ul>
# </div>
# <div class="layered_filter">
# <div class="layered_subtitle_heading">
# <span class="layered_subtitle">Language</span>
# <!--<span class="layered_close">
#                             	<a href="#" data-rel="ul_layered_id_feature_10"></a>
#                             </span>-->
# </div>
# <ul class="col-lg-12 layered_filter_ul" id="ul_layered_id_feature_10">
# <li class="nomargin hiddable col-lg-12">
# <input class="checkbox" id="layered_id_feature_124" name="layered_id_feature_124" type="checkbox" value="124_10"/>
# <label for="layered_id_feature_124">
# <a data-rel="nofollow" href="https://www.misterchrono.com/en/126-watch-bookstore#language-english">English<span> (12)</span></a>
# </label>
# </li>
# <li class="nomargin hiddable col-lg-12">
# <input class="checkbox" id="layered_id_feature_123" name="layered_id_feature_123" type="checkbox" value="123_10"/>
# <label for="layered_id_feature_123">
# <a data-rel="nofollow" href="https://www.misterchrono.com/en/126-watch-bookstore#language-french">French<span> (15)</span></a>
# </label>
# </li>
# </ul>
# </div>
# </div>
# <input name="id_category_layered" type="hidden" value="126"/>
# </form>
# </div>
# <div id="layered_ajax_loader" style="display: none;">
# <p>
# <img alt="" src="https://www.misterchrono.com/img/loader.gif"/>
# <br/>Loading...
# 		</p>
# </div>
# </div>
# </section>
# <!-- Center -->
# <section class="col-md-9" id="center_column">
# <h1 class="page-heading product-listing">
# <span class="cat-name">
# 		Watch Bookstore 		</span>
# </h1>
# <small class="heading-counter">There are 36 products.</small>
# <div class="content_sortPagiBar clearfix">
# <div class="sortPagiBar clearfix row">
# <div class="col-md-10 col-sm-8 col-xs-6">
# <div class="sort">
# <div class="display hidden-xs pull-left">
# <label class="sort-title pull-left">View</label>
# <div id="list"><a href="#" rel="nofollow" title="List"><i class="fa fa-th-list"></i></a></div>
# <div id="grid"><a href="#" rel="nofollow" title="Grid"><i class="fa fa-th-large"></i></a></div>
# </div>
# <form action="https://www.misterchrono.com/en/126-watch-bookstore" class="productsSortForm form-horizontal pull-left hidden-xs" id="productsSortForm">
# <div class="select">
# <label for="selectProductSort">Sort by</label>
# <select class="selectProductSort form-control" id="selectProductSort">
# <option selected="selected" value="date_add:desc">default</option>
# <option value="price:asc">Price: Lowest first</option>
# <option value="price:desc">Price: Highest first</option>
# <option value="name:asc">Product Name: A to Z</option>
# <option value="name:desc">Product Name: Z to A</option>
# <option value="quantity:desc">In stock</option>
# <option value="reference:asc">Reference: Lowest first</option>
# <option value="reference:desc">Reference: Highest first</option>
# </select>
# </div>
# </form>
# <!-- /Sort products -->
# <!-- nbr product/page -->
# <!-- /nbr product/page -->
# </div>
# </div>
# <div class="product-compare col-md-2 col-sm-4 col-xs-6">
# </div>
# </div>
# </div>
# <!-- Products list -->
# <div class="product_list grid row product-list-1462214971" id="product_list">
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 first-in-line first-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="4171"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" itemprop="url" title="Rolex  History, Icons and Record-Breaking Models">
# <img alt="CHRONOMASTER ONLY" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/14648-home_default/rolex-philosophy.jpg" title="CHRONOMASTER ONLY" width="250"/>
# <span class="product-additional" data-idproduct="4171"></span>
# </a>
# <a class="new-box" href="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html">
# <span class="label-new product-label label-info label">New</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" href="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" itemprop="url" title="Rolex  History, Icons and Record-Breaking Models">
# 		Rolex  History, Icons and Record-Breaking...
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				38,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="4171" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=4171&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 last-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="4167"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/4167-investing-in-wristwatches-rolex-3050262344227.html" itemprop="url" title="Investing in wristwatches: Rolex">
# <img alt="Investing in wristwatches: Rolex" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/14605-home_default/investing-in-wristwatches-rolex.jpg" title="Investing in wristwatches: Rolex" width="250"/>
# <span class="product-additional" data-idproduct="4167"></span>
# </a>
# <a class="new-box" href="https://www.misterchrono.com/en/watch-bookstore/4167-investing-in-wristwatches-rolex-3050262344227.html">
# <span class="label-new product-label label-info label">New</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/4167-investing-in-wristwatches-rolex-3050262344227.html" href="https://www.misterchrono.com/en/watch-bookstore/4167-investing-in-wristwatches-rolex-3050262344227.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/4167-investing-in-wristwatches-rolex-3050262344227.html" itemprop="url" title="Investing in wristwatches: Rolex">
# 		Investing in wristwatches: Rolex
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				85,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="4167" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=4167&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 last-in-line first-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="4166"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/4166-patek-philippe-investing-in-wristwatches-3050262344227.html" itemprop="url" title="Patek Philippe: Investing in Wristwatches">
# <img alt="CHRONOMASTER ONLY" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/14595-home_default/patek-philippe-investing-in-wristwatches.jpg" title="CHRONOMASTER ONLY" width="250"/>
# <span class="product-additional" data-idproduct="4166"></span>
# </a>
# <a class="new-box" href="https://www.misterchrono.com/en/watch-bookstore/4166-patek-philippe-investing-in-wristwatches-3050262344227.html">
# <span class="label-new product-label label-info label">New</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/4166-patek-philippe-investing-in-wristwatches-3050262344227.html" href="https://www.misterchrono.com/en/watch-bookstore/4166-patek-philippe-investing-in-wristwatches-3050262344227.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/4166-patek-philippe-investing-in-wristwatches-3050262344227.html" itemprop="url" title="Patek Philippe: Investing in Wristwatches">
# 		Patek Philippe: Investing in Wristwatches
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				95,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="4166" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=4166&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 first-in-line last-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="4165"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/4165-rolex-cosmograph-daytona-vol-1-manual-winding-models-1963-1988-3050262344227.html" itemprop="url" title="Rolex Cosmograph Daytona  Vol. 1: Manual Winding Models (1963-1988)">
# <img alt="CHRONOMASTER ONLY" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/14584-home_default/rolex-cosmograph-daytona-vol-1-manual-winding-models-1963-1988.jpg" title="CHRONOMASTER ONLY" width="250"/>
# <span class="product-additional" data-idproduct="4165"></span>
# </a>
# <a class="new-box" href="https://www.misterchrono.com/en/watch-bookstore/4165-rolex-cosmograph-daytona-vol-1-manual-winding-models-1963-1988-3050262344227.html">
# <span class="label-new product-label label-info label">New</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/4165-rolex-cosmograph-daytona-vol-1-manual-winding-models-1963-1988-3050262344227.html" href="https://www.misterchrono.com/en/watch-bookstore/4165-rolex-cosmograph-daytona-vol-1-manual-winding-models-1963-1988-3050262344227.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# ...
# 		La Cote de montres modernes et de...
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				60,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="1819" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=1819&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 last-in-line first-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="1327"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/1327-l-annuel-des-montres-2013-catalogue-raisonne-des-modeles-et-des-fabricants-3050132744225.html" itemprop="url" title="L'annuel des montres 2013: Catalogue raisonné des modèles et des fabricants">
# <img alt="L'annuel des montres 2013: Catalogue raisonné des modèles et des fabricants" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/2582-home_default/l-annuel-des-montres-2013-catalogue-raisonne-des-modeles-et-des-fabricants.jpg" title="L'annuel des montres 2013: Catalogue raisonné des modèles et des fabricants" width="250"/>
# <span class="product-additional" data-idproduct="1327"></span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/1327-l-annuel-des-montres-2013-catalogue-raisonne-des-modeles-et-des-fabricants-3050132744225.html" href="https://www.misterchrono.com/en/watch-bookstore/1327-l-annuel-des-montres-2013-catalogue-raisonne-des-modeles-et-des-fabricants-3050132744225.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/1327-l-annuel-des-montres-2013-catalogue-raisonne-des-modeles-et-des-fabricants-3050132744225.html" itemprop="url" title="L'annuel des montres 2013: Catalogue raisonné des modèles et des fabricants">
# 		L'annuel des montres 2013: Catalogue...
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				45,79 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="1327" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=1327&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 first-in-line last-line last-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="1056"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/1056-la-mecanique-du-geste-3050105644224.html" itemprop="url" title="La mécanique du geste">
# <img alt="Montres de stars" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/1613-home_default/la-mecanique-du-geste.jpg" title="Montres de stars" width="250"/>
# <span class="product-additional" data-idproduct="1056"></span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/1056-la-mecanique-du-geste-3050105644224.html" href="https://www.misterchrono.com/en/watch-bookstore/1056-la-mecanique-du-geste-3050105644224.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/1056-la-mecanique-du-geste-3050105644224.html" itemprop="url" title="La mécanique du geste">
# 		La mécanique du geste
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				19,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="1056" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=1056&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 last-line first-item-of-tablet-line last-item-of-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="346"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/346-theorie-d-horlogerie-3050034644227.html" itemprop="url" title="Théorie d'horlogerie">
# <img alt="Théorie d'horlogerie" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/334-home_default/theorie-d-horlogerie.jpg" title="Théorie d'horlogerie" width="250"/>
# <span class="product-additional" data-idproduct="346"></span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/346-theorie-d-horlogerie-3050034644227.html" href="https://www.misterchrono.com/en/watch-bookstore/346-theorie-d-horlogerie-3050034644227.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/346-theorie-d-horlogerie-3050034644227.html" itemprop="url" title="Théorie d'horlogerie">
# 		Théorie d'horlogerie
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				179,00 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="346" data-id-product-attribute="20491" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=346&amp;ipa=20491&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# <div class="ajax_block_product col-sp-12 col-xs-12 col-sm-6 col-md-4 last-in-line last-line last-item-of-tablet-line last-item-of-mobile-line last-mobile-line">
# <div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="31"></div>
# <a class="product_img_link" href="https://www.misterchrono.com/en/watch-bookstore/31-montres-de-judith-miller-3050003144222.html" itemprop="url" title="Montres de Judith Miller">
# <img alt="Montres de Judith Miller" class="replace-2x img-responsive" height="250" itemprop="image" src="https://www.misterchrono.com/31-home_default/montres-de-judith-miller.jpg" title="Montres de Judith Miller" width="250"/>
# <span class="product-additional" data-idproduct="31"></span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\quick_view -->
# <div class="quickview">
# <a class="quick-view" data-link="https://www.misterchrono.com/en/watch-bookstore/31-montres-de-judith-miller-3050003144222.html" href="https://www.misterchrono.com/en/watch-bookstore/31-montres-de-judith-miller-3050003144222.html" title="Quick View">
# <i class="fa fa-eye"></i><span>Quick View</span>
# </a>
# </div>
# </div><div class="right-block"><div class="product-meta">
# <!-- @file modules\appagebuilder\views\templates\front\products\color -->
# <div class="color-list-container"> </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\name -->
# <h5 class="name" itemprop="name">
# <a class="product-name" href="https://www.misterchrono.com/en/watch-bookstore/31-montres-de-judith-miller-3050003144222.html" itemprop="url" title="Montres de Judith Miller">
# 		Montres de Judith Miller
# 	</a>
# </h5>
# <!-- @file modules\appagebuilder\views\templates\front\products\price -->
# <div class="content_price">
# <span class="price product-price">
# 				9,95 €			</span>
# </div>
# <div class="functional-buttons clearfix">
# <!-- @file modules\appagebuilder\views\templates\front\products\add_to_cart -->
# <div class="cart">
# <a class="button ajax_add_to_cart_button btn btn-outline" data-id-product="31" data-id-product-attribute="0" data-minimal_quantity="1" href="https://www.misterchrono.com/en/panier?add=1&amp;id_product=31&amp;token=2649f232fa66a36820c757455e61e85e" rel="nofollow" title="Add to cart">
# <span>Add to cart</span>
# </a>
# </div>
# <!-- @file modules\appagebuilder\views\templates\front\products\wishlist -->
# <!-- @file modules\appagebuilder\views\templates\front\products\compare -->
# </div></div></div></div>
# </div>
# </div>
# <div class="content_sortPagiBar bottom">
# <div class="bottom-pagination-content clearfix row">
# <div class="col-md-12 col-sm-12 col-xs-12">
# <!-- Pagination -->
# <div class="pagination clearfix" id="pagination_bottom">
# </div>
# <!-- /Pagination -->
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# </section>
# <!-- Footer -->
# <footer class="footer-container" id="footer">
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="footer-link container footer-block">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-4 col-lg-4 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGeneral -->
# <div class="ApHtml block">
# <h4 class="title_block">About our company</h4>
# <div class="toggle-footer"><p dir="ltr">The world of horology is a field that combines precision and patience.<br/>Passionate about this world and luxury watches, in 2009, four partners and friends decided to found a company that offers accessories related to high-end luxury watchmaking. This is the beginning of MisterChrono Paris.</p></div><p> </p>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-4 col-lg-4 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApBlockLink -->
# <div class="ApBlockLink" id="blockLink-form_9389890224009748">
# <div class="block">
# <h4 class="title_block">
# 					useful links
# 				</h4>
# <ul class="toggle-footer list-group bullet">
# <li><a href="https://www.misterchrono.com/en/content/46-histoire">About Us</a></li>
# <li><a href="https://www.misterchrono.com/en/content/37-conditions-generales-de-vente-en-ligne-">Privacy Policy</a></li>
# <li><a href="https://www.misterchrono.com/en/content/37-conditions-generales-de-vente-en-ligne-">Terms &amp; Conditions</a></li>
# <li><a href="https://www.misterchrono.com/en/content/40-nous-recrutons">Join Us</a></li>
# <li><a href="https://www.misterchrono.com/en/content/41-Join-the-MisterChrono-network-">Franchise</a></li>
# <li><a href="https://www.misterchrono.com/en/content/47-return-and-refund">return and refund</a></li>
# </ul>
# </div>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-12 col-xs-12 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- MODULE Block contact infos -->
# <div class="footer-block block" id="block_contact_infos">
# <div>
# <h4 class="title_block">Contact us</h4>
# <ul class="toggle-footer">
# <li class="local">
#             		MisterChrono Paris<br/>23 rue danielle casanova
# 75001 Paris            	</li>
# <li class="phone">
# <i class="fa fa-phone"></i>
# <span>09 53 42 04 64</span>
# </li>
# <li class="email">
# <i class="fa fa-envelope"></i>
# <span><a href="mailto:%63%6f%6e%74%61%63%74@%6d%69%73%74%65%72%63%68%72%6f%6e%6f.%63%6f%6d">contact@misterchrono.com</a></span>
# </li>
# </ul>
# </div>
# </div>
# <!-- /MODULE Block contact infos -->
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="footer-copyright">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\header -->
# <script type="text/javascript">
#         var leoOption = {
# 		productNumber:1,
# 		productInfo:0,
# 		productTran:1,
# 		productCdown: 1,
# 		productColor: 1,
# 		homeWidth: 250,
# 		homeheight: 250,
# 	}
#
#         $(document).ready(function(){
#             var leoCustomAjax = new $.LeoCustomAjax();
#             leoCustomAjax.processAjax();
#         });
# 	// Javascript code
# </script>
# </footer>
# </section><!-- #page -->
# <div id="back-top"><a class="fa fa-angle-up" href="#"></a></div>
# </body></html>

# %%
#Scrape links first
Links = soup.find_all('a', attrs={'class':"product-name"})

# %%
# To go into one link and extract all the details we require about a watch
product_link = Links[0].get('href')# extracts the actual link to product
product_link
# Out:
# 'https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html'

# %%
# Link HTTPS REQUEST
new_page = requests.get(product_link, headers=Header)

# %%
#To convert new link page into HTML Format
new_soup = bs(new_page.content,'html.parser')

# %%
new_soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-us"><![endif]-->
# <!--[if IE 7]><html class="no-js lt-ie9 lt-ie8 ie7" lang="en-us"><![endif]-->
# <!--[if IE 8]><html class="no-js lt-ie9 ie8" lang="en-us"><![endif]-->
# <!--[if gt IE 8]> <html class="no-js ie9" lang="en-us"><![endif]-->
# <html class="default" lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <title>Rolex  History, Icons and Record-Breaking Models</title>
# <meta content="Rolex
#
# History, Icons and Record-Breaking Models" name="description"/>
# <meta content="PrestaShop" name="generator"/>
# <meta content="index,follow" name="robots"/>
# <meta content="width=device-width, minimum-scale=0.25, maximum-scale=1.6, initial-scale=1.0" name="viewport"/> <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link href="/img/favicon.ico?1697125177" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/img/favicon.ico?1697125177" rel="shortcut icon" type="image/x-icon"/>
# <link href="/themes/leo_mayshop/css/global.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/fancybox/jquery.fancybox.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/product.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/bxslider/jquery.bxslider.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/socialsharing/css/socialsharing.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcurrencies/blockcurrencies.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocklanguages/blocklanguages.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcontact/blockcontact.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocksearch/blocksearch.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/plugins/autocomplete/jquery.autocomplete.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/product_list.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocktopmenu/css/blocktopmenu.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blocktopmenu/css/superfish-modified.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/themeconfigurator/css/hooks.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockgrouptop/blockgrouptop.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoblog/assets/leoblog.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leomenusidebar/leomenusidebar.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/typo/typo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/iView/iview.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leoslideshow/views/css/iView/skin_4_responsive/style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/ApImageHotspot.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.core.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.slider.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery/ui/themes/base/jquery.ui.theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/ApImage360.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/appagebuilder/views/css/animate.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/owl.carousel.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/owl.theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/appagebuilder/views/css/styles.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/leobootstrapmenu/megamenu.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockuserinfo/blockuserinfo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/productcomments/productcomments.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockcart/blockcart.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/modules/blockwishlist/blockwishlist.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/ets_advancedcaptcha/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/themes/leo_mayshop/css/responsive.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/productcomposer/views/css/front/pc_cart.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/modules/productcomposer/views/css/front/six.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var CUSTOMIZE_TEXTFIELD = 1;
# var FancyboxI18nClose = 'Close';
# var FancyboxI18nNext = 'Next';
# var FancyboxI18nPrev = 'Previous';
# var PS_CATALOG_MODE = false;
# var added_to_wishlist = 'The product was successfully added to your wishlist.';
# var ajax_allowed = true;
# var ajaxsearch = true;
# var allowBuyWhenOutOfStock = true;
# var attribute_anchor_separator = '-';
# var attributesCombinations = [];
# var availableLaterValue = '';
# var availableNowValue = 'in stock';
# var baseDir = 'https://www.misterchrono.com/';
# var baseUri = 'https://www.misterchrono.com/';
# var blocksearch_type = 'top';
# var blockwishlist_add = 'The product was successfully added to your wishlist';
# var blockwishlist_remove = 'The product was successfully removed from your wishlist';
# var blockwishlist_viewwishlist = 'View your wishlist';
# var comparator_max_item = 0;
# var confirm_report_message = 'Are you sure that you want to report this comment?';
# var contentOnly = false;
# var currency = {"id":1,"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac","blank":"1","conversion_rate":"1.000000","deleted":"0","format":"2","decimals":"1","active":"1","prefix":"","suffix":" \u20ac","id_shop_list":null,"force_id":false};
# var currencyBlank = 1;
# var currencyFormat = 2;
# var currencyRate = 1;
# var currencySign = '€';
# var currentDate = '2024-02-24 23:19:07';
# var customerGroupWithoutTax = false;
# var customizationFields = false;
# var customizationId = null;
# var customizationIdMessage = 'Customization #';
# var default_eco_tax = 0;
# var delete_txt = 'Delete';
# var displayList = false;
# var displayPrice = 0;
# var doesntExist = 'This combination does not exist for this product. Please select another combination.';
# var doesntExistNoMore = 'This product is no longer in stock';
# var doesntExistNoMoreBut = 'with those attributes but is available with others.';
# var ecotaxTax_rate = 0;
# var fieldRequired = 'Please fill in all the required fields before saving your customization.';
# var freeProductTranslation = 'Free!';
# var freeShippingTranslation = 'Free shipping!';
# var generated_date = 1708813147;
# var groupReduction = 0;
# var hasDeliveryAddress = false;
# var highDPI = false;
# var idDefaultImage = 14648;
# var id_lang = 1;
# var id_product = 4171;
# var img_dir = 'https://www.misterchrono.com/themes/leo_mayshop/img/';
# var img_prod_dir = 'https://www.misterchrono.com/img/p/';
# var img_ps_dir = 'https://www.misterchrono.com/img/';
# var instantsearch = true;
# var isGuest = 0;
# var isLogged = 0;
# var isMobile = false;
# var isPsVersion17 = false;
# var is_seven = false;
# var jqZoomEnabled = false;
# var loggin_required = 'You must be logged in to manage your wishlist.';
# var maxQuantityToAllowDisplayOfLastQuantityMessage = 2;
# var minimalQuantity = 1;
# var moderation_active = true;
# var mywishlist_url = 'https://www.misterchrono.com/en/module/blockwishlist/mywishlist';
# var nbr_images = '25';
# var noTaxForThisProduct = false;
# var oosHookJsCodeFunctions = [];
# var page_name = 'product';
# var pc_config = {"id_product":4171,"id_layout":"1","columns":"2","active":"0","required":"0","popup":0,"manage_quantity":"0","title":{"1":"","2":"","3":"","4":"","5":"","6":"","7":""},"primary_color":"#B1E4F9","secondary_color":"#F8E955","invert_groups":false,"allow_upload":"0","allow_text":"0","text_on_top":"0","display_picker":"0","max_upload":"0.00","upload_cost":"0.000000","total_upload_cost":"0.000000","empty":"\/modules\/productcomposer\/views\/img\/empty.png","bg":"4171.png?1707199395","bgThumb":"4171-thumb.png?1707199395","mask":false,"maskThumb":false,"id":4171,"id_shop_list":null,"force_id":false};
# var pc_icon_height = 150;
# var pc_link = 'https://www.misterchrono.com/en/module/productcomposer/default';
# var pc_link_selection = 'https://www.misterchrono.com/en/module/productcomposer/selection';
# var pc_link_text = 'https://www.misterchrono.com/en/module/productcomposer/text';
# var pc_module_dir = 'https://www.misterchrono.com/modules/productcomposer/';
# var pc_special = 3486;
# var pc_tax = 0;
# var pc_version = '1.8.6';
# var priceDisplayMethod = 0;
# var priceDisplayPrecision = 2;
# var productAvailableForOrder = true;
# var productBasePriceTaxExcl = 31.666667;
# var productBasePriceTaxExcluded = 31.666667;
# var productBasePriceTaxIncl = 38;
# var productHasAttributes = false;
# var productPrice = 38;
# var productPriceTaxExcluded = 31.666667;
# var productPriceTaxIncluded = 38;
# var productPriceWithoutReduction = 38;
# var productReference = 'WP - Rolex History';
# var productShowPrice = true;
# var productUnitPriceRatio = 0;
# var product_fileButtonHtml = 'Choose File';
# var product_fileDefaultHtml = 'No file selected';
# var product_specific_price = [];
# var productcomment_added = 'Your comment has been added!';
# var productcomment_added_moderation = 'Your comment has been added and will be available once approved by a moderator.';
# var productcomment_ok = 'OK';
# var productcomment_title = 'New comment';
# var productcomments_controller_url = 'https://www.misterchrono.com/en/module/productcomments/default';
# var productcomments_url_rewrite = true;
# var productcompare_add = 'The product has been added to list compare';
# var productcompare_remove = 'The product was successfully removed from list compare';
# var productcompare_url = 'https://www.misterchrono.com/en/comparaison-produits';
# var productcompare_viewlistcompare = 'View list compare';
# var ps_module_dev = false;
# var pslookbook_url = 'https://www.misterchrono.com/en/module/pslookbook/FrontImageDisplay';
# var quantitiesDisplayAllowed = false;
# var quantityAvailable = 0;
# var quickView = true;
# var reduction_percent = 0;
# var reduction_price = 0;
# var removingLinkText = 'remove this product from my cart';
# var roundMode = 2;
# var search_url = 'https://www.misterchrono.com/en/recherche';
# var secure_key = 'a3ac64f29783655bcbd8bb07b1c389aa';
# var sharing_img = 'https://www.misterchrono.com/14648/rolex-philosophy.jpg';
# var sharing_name = 'Rolex  History, Icons and Record-Breaking Models';
# var sharing_url = 'https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html';
# var specific_currency = false;
# var specific_price = 0;
# var static_token = '2649f232fa66a36820c757455e61e85e';
# var stock_management = 1;
# var taxRate = 20;
# var toBeDetermined = 'To be determined';
# var token = '2649f232fa66a36820c757455e61e85e';
# var uploading_in_progress = 'Uploading in progress, please be patient.';
# var url_upload = 'https://www.misterchrono.com/modules/pslookbook/upload/';
# var usingSecureMode = true;
# var wishlistProductsIds = false;
# </script>
# <script src="/js/jquery/jquery-1.11.0.min.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.easing.js" type="text/javascript"></script>
# <script src="/js/tools.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/global.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/10-bootstrap.min.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/15-jquery.total-storage.min.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/autoload/15-jquery.uniform-modified.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/fancybox/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.idTabs.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.scrollTo.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/jquery.serialScroll.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/bxslider/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/product.js" type="text/javascript"></script>
# <script src="/modules/socialsharing/js/socialsharing.js" type="text/javascript"></script>
# <script src="/js/jquery/plugins/autocomplete/jquery.autocomplete.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocksearch/blocksearch.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/hoverIntent.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/superfish-modified.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blocktopmenu/js/blocktopmenu.js" type="text/javascript"></script>
# <script src="/modules/leoslideshow/views/js/iView/raphael-min.js" type="text/javascript"></script>
# <script src="/modules/leoslideshow/views/js/iView/iview.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/ApImageHotspot.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.core.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.widget.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.mouse.min.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery.ui.slider.min.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/ApImage360.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/waypoints.min.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/jquery.stellar.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/owl.carousel.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/countdown.js" type="text/javascript"></script>
# <script src="/modules/appagebuilder/views/js/script.js" type="text/javascript"></script>
# <script src="/modules/productcomments/js/jquery.rating.pack.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blockcart/ajax-cart.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/blockwishlist/js/ajax-wishlist.js" type="text/javascript"></script>
# <script src="/modules/ets_advancedcaptcha/views/js/front.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/pc_tools.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/tn_compat.js" type="text/javascript"></script>
# <script src="/modules/productcomposer/views/js/front/pc_cart.js" type="text/javascript"></script>
# <script src="/modules/lyoshowvatfree/views/js/product9.js" type="text/javascript"></script>
# <script src="/modules/productcomments/js/jquery.textareaCounter.plugin.js" type="text/javascript"></script>
# <script src="/themes/leo_mayshop/js/modules/productcomments/js/productcomments.js" type="text/javascript"></script>
# <meta content="product" property="og:type"/>
# <meta content="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" property="og:url"/>
# <meta content="Rolex  History, Icons and Record-Breaking Models" property="og:title"/>
# <meta content="MisterChrono" property="og:site_name"/>
# <meta content="Rolex
#
# History, Icons and Record-Breaking Models" property="og:description"/>
# <meta content="https://www.misterchrono.com/14648-large_default/rolex-philosophy.jpg" property="og:image"/>
# <meta content="31.67" property="product:pretax_price:amount"/>
# <meta content="EUR" property="product:pretax_price:currency"/>
# <meta content="38" property="product:price:amount"/>
# <meta content="EUR" property="product:price:currency"/>
# <meta content="1.000000" property="product:weight:value"/>
# <meta content="kg" property="product:weight:units"/>
# <script type="text/javascript">
#     var pc_message = {
#         error   : 'An error occurred',
#         confirm   : 'Are you sure you want to delete this item?',
#         required  : 'The group \"_group_\" is required. Please choose an option and retry',
#         required_field  : 'The field \"_field_\" is required. Please fill it',
#         required_design : 'Please design your product first'
#     };
# </script>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,600&amp;subset=latin,latin-ext" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Playfair+Display" rel="stylesheet" type="text/css"/>
# <!-- font-family: 'Playfair Display', serif; -->
# <!--[if IE 8]>
# 		<script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# 		<script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
# 		<![endif]-->
# </head>
# <body class="product product-4171 product-rolex-philosophy category-126 category-watch-bookstore show-left-column hide-right-column lang_en fullwidth header-default" id="product">
# <section data-column="col-xs-12 col-sm-6 col-md-4" data-type="grid" id="page">
# <!-- Header -->
# <header class="header-center" id="header">
# <section class="header-container">
# <div class="header-left" id="header-main">
# <div id="header_content">
# <div class="inner">
# <div class="top">
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="header-top container">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-4 col-xs-6 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGeneral -->
# <div class="ApHtml block">
# <p>Phone: +33 (0)953420464 <span>- </span>WhatsApp:+33 686153329</p>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-center col-lg-4 col-md-4 col-sm-5 col-xs-6 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block currencies module -->
# <!-- /Block currencies module -->
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block user information module NAV  -->
# <div class="header_user_info popup-over e-translate-top tool-topbar">
# <div class="popup-title" data-toggle="dropdown"><span>Setting</span></div>
# <ul class="links popup-content">
# <li><a class="login" href="https://www.misterchrono.com/en/mon-compte" rel="nofollow" title="Login to your customer account">
# <i class="fa fa-unlock-alt"></i>Sign in
#    </a></li>
# <li>
# <a href="https://www.misterchrono.com/en/mon-compte" title="My account"><i class="fa fa-user"></i>My Account</a>
# </li>
# <li class="last"><a class="last" href="https://www.misterchrono.com/en/commande" title="Checkout"><i class="fa fa-share"></i>Checkout</a></li>
# <li class="first">
# <a href="https://www.misterchrono.com/en/module/blockwishlist/mywishlist" id="wishlist-total" title="My wishlists">
# <i class="fa fa-heart"></i>Wish List<span class="ap-total-wishlist ap-total"></span></a>
# </li>
# <li>
# <a href="https://www.misterchrono.com/en/comparaison-produits" rel="nofollow" title="Compare">
# <i class="fa fa-compress"></i>Compare<span class="ap-total-compare ap-total"></span>
# </a>
# </li>
# </ul>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block languages module -->
# <div class="popup-over e-scale">
# <div class="popup-title" data-toggle="dropdown"><a href="#" title="Languages">
# <span>English</span>
# </a>
# </div>
# <div class="popup-content">
# <div class="languages-block" id="languages-block-top">
# <ul class="languages-block_ul" id="first-languages">
# <li class="selected">
# <span><img alt="en" height="11" src="https://www.misterchrono.com/img/l/1.jpg" width="16"/> English</span>
# </li>
# <li>
# <a href="https://www.misterchrono.com/fr/librairie-horlogere/4171-rolex-histoire-icones-et-modeles-record-3050262344227.html" title="Français (French)">
# <span><img alt="fr" height="11" src="https://www.misterchrono.com/img/l/2.jpg" width="16"/> Français</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- /Block languages module -->
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-3 col-xs-12 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- MODULE Block cart -->
# <div class="blockcart_top clearfix pull-right">
# <div class="shopping_cart pull-right" id="cart">
# <a href="https://www.misterchrono.com/en/commande" rel="nofollow" title="View my shopping cart">
# <div class="cart-inner media-body pull-left">
# <h4>Cart</h4>
# </div>
# <div class="title-cart pull-left">
# <div class="cart-quantity">
# <span class="ajax_cart_quantity unvisible">0</span>
# <span class="ajax_cart_no_product">0</span>
# </div>
# </div>
# </a>
# <div class="cart_block block exclusive">
# <div class="block_content">
# <!-- block list of products -->
# <div class="cart_block_list">
# <p class="cart_block_no_products">
# 							No products
# 						</p>
# <div class="cart-prices">
# <div class="cart-prices-line first-line">
# <span class="price cart_block_shipping_cost ajax_cart_shipping_cost unvisible">
# 																			 To be determined																	</span>
# <span class="unvisible">
# 									Shipping
# 								</span>
# </div>
# <div class="cart-prices-line">
# <span class="price cart_block_tax_cost ajax_cart_tax_cost">0,00 €</span>
# <span>Tax</span>
# </div>
# <div class="cart-prices-line last-line">
# <span class="price cart_block_total ajax_block_cart_total">0,00 €</span>
# <span>Total</span>
# </div>
# <p>
# 																	Prices are tax included
# 																</p>
# </div>
# <p class="cart-buttons clearfix">
# <a class="btn btn-warning button-medium button button-small pull-right" href="https://www.misterchrono.com/en/commande" id="button_order_cart" rel="nofollow" title="Check out">
# <span>
# 									Check out
# 								</span>
# </a>
# </p>
# </div>
# </div>
# </div><!-- .cart_block -->
# </div>
# </div>
# <div id="layer_cart">
# <div class="clearfix">
# <div class="layer_cart_product col-xs-12 col-md-6">
# <span class="cross" title="Close window"></span>
# <span class="title">
# <i class="fa fa-ok"></i>Product successfully added to your shopping cart
# 				</span>
# <div class="product-image-container layer_cart_img">
# </div>
# <div class="layer_cart_product_info">
# <span class="product-name" id="layer_cart_product_title"></span>
# <span id="layer_cart_product_attributes"></span>
# <div>
# <strong class="dark">Quantity</strong>
# <span id="layer_cart_product_quantity"></span>
# </div>
# <div>
# <strong class="dark">Total</strong>
# <span id="layer_cart_product_price"></span>
# </div>
# </div>
# </div>
# <div class="layer_cart_cart col-xs-12 col-md-6">
# <span class="title">
# <!-- Plural Case [both cases are needed because page may be updated in Javascript] -->
# <span class="ajax_cart_product_txt_s unvisible">
# 						There are <span class="ajax_cart_quantity">0</span> items in your cart.
# 					</span>
# <!-- Singular Case [both cases are needed because page may be updated in Javascript] -->
# <span class="ajax_cart_product_txt">
# 						There is 1 item in your cart.
# 					</span>
# </span>
# <div class="layer_cart_row">
# <strong class="dark">
# 						Total products
# 																					(tax incl.)
# 																		</strong>
# <span class="ajax_block_products_total">
# </span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark unvisible">
# 						Total shipping (tax incl.)					</strong>
# <span class="ajax_cart_shipping_cost unvisible">
# 													 To be determined											</span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark">Tax</strong>
# <span class="price cart_block_tax_cost ajax_cart_tax_cost">0,00 €</span>
# </div>
# <div class="layer_cart_row">
# <strong class="dark">
# 						Total
# 																					(tax incl.)
# 																		</strong>
# <span class="ajax_block_cart_total">
# </span>
# </div>
# <div class="button-container">
# <span class="continue btn btn-outline button exclusive-medium" title="Continue shopping">
# <span>
# 							Continue shopping
# 						</span>
# </span>
# <a class="btn btn-warning button pull-right" href="https://www.misterchrono.com/en/commande" rel="nofollow" title="Proceed to checkout">
# <span>
# 							Proceed to checkout
# 						</span>
# </a>
# </div>
# </div>
# </div>
# <div class="crossseling"></div>
# </div> <!-- #layer_cart -->
# <div class="layer_cart_overlay"></div>
# <!-- /MODULE Block cart -->
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- Block search module TOP -->
# <div class="popup-over pull-right e-translate-down" id="search_block_top">
# <span class="fa fa-search" title="Search"></span>
# <form action="//www.misterchrono.com/en/recherche" id="searchbox" method="get">
# <input name="controller" type="hidden" value="search"/>
# <input name="orderby" type="hidden" value="position"/>
# <input name="orderway" type="hidden" value="desc"/>
# <input class="search_query form-control" id="search_query_top" name="search_query" placeholder="Search" type="text" value=""/>
# <button class="btn btn-outline-inverse fa fa-search" name="submit_search" type="submit"> </button>
# </form>
# </div>
# <!-- /Block search module TOP -->
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="container">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGenCode -->
# <div id="header_logo"> <a href="https://www.misterchrono.com/" title="MisterChrono"> <img alt="MisterChrono" class="logo img-responsive" height="50" src="https://www.misterchrono.com/img/misterchrono-paris-logo-1566525515.jpg" width="401"/> </a> </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div class="clearfix" id="leo-megamenu">
# <nav class="sf-contener leo-megamenu" id="cavas_menu">
# <div role="navigation">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button class="navbar-toggle btn-outline-inverse" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="fa fa-bars"></span>
# </button>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse navbar-ex1-collapse" id="leo-top-menu">
# <ul class="nav navbar-nav megamenu"><li class="parent dropdown">
# <a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/index.php" target="_self"><span class="menu-title">Home</span><b class="caret"></b></a><div class="dropdown-sub dropdown-menu"><div class="dropdown-menu-inner"><div class="row"><div class="mega-col col-sm-12"> <div class="mega-col-inner"></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch straps</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/344-watch-straps" target="_self"><span class="menu-title">Ready to wear straps  </span></a></li><li class=""><a href="https://www.misterchrono.com/en/accessories-visibles/3485-camille-fournet-bespoke-product-3050348544220.html" target="_self"><span class="menu-title">Bespoke made straps</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch Maintenance</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/103-watchmaker-tools" target="_self"><span class="menu-title">Watch tools</span></a></li><li class=""><a href="https://www.misterchrono.com/en/content/30-watch-service" target="_self"><span class="menu-title">Our service center</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Watch Protection</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/144-safe" target="_self"><span class="menu-title">Safes for watches</span></a></li><li class=""><a href="https://www.misterchrono.com/en/96-watchwinders" target="_self"><span class="menu-title">Watchwinders</span></a></li><li class=""><a href="https://www.misterchrono.com/en/106-watch-boxes" target="_self"><span class="menu-title">Watch boxes</span></a></li><li class=""><a href="https://www.misterchrono.com/en/102-traveler-cases-for-watches" target="_self"><span class="menu-title">Watch travel cases</span></a></li><li class=""><a href="https://www.misterchrono.com/en/content/43-service-sur-mesure" target="_self"><span class="menu-title">Our customisation center</span></a></li></ul></div></div></div></div></div></li><li class="parent dropdown"><a class="dropdown-toggle has-category" data-toggle="dropdown" href="https://www.misterchrono.com/en/#" target="_self"><span class="menu-title">Lifestyle</span><b class="caret"></b></a><div class="dropdown-menu level1"><div class="dropdown-menu-inner"><div class="row"><div class="col-sm-12 mega-col" data-colwidth="12" data-type="menu"><div class="inner"><ul><li class=""><a href="https://www.misterchrono.com/en/126-watch-bookstore" target="_self"><span class="menu-title">Bookstore</span></a></li><li class=""><a href="https://www.misterchrono.com/en/161-boutons-de-manchette" target="_self"><span class="menu-title">Cufflinks</span></a></li><li class=""><a href="https://www.misterchrono.com/en/228-belts-and-bracelets-" target="_self"><span class="menu-title">Belts and bracelets</span></a></li><li class=""><a href="https://www.misterchrono.com/en/232-clothes" target="_self"><span class="menu-tit ...
# <a class="has-category" href="https://www.misterchrono.com/en/227-sales" target="_self"><span class="menu-title">Sales</span></a></li><li class="">
# <a class="has-category" href="https://www.misterchrono.com/en/content/44-gallery" target="_self"><span class="menu-title">Gallery</span></a></li><li class="">
# <a class="has-category" href="https://www.misterchrono.com/en/blog.html" target="_self"><span class="menu-title">Blog</span></a></li></ul>
# </div>
# </div>
# </nav>
# </div>
# <script type="text/javascript">
# // <![CDATA[
# 	var current_link = "http://www.misterchrono.com/en/";
# 	//alert(request);
#     var currentURL = window.location;
#     currentURL = String(currentURL);
#     currentURL = currentURL.replace("https://","").replace("http://","").replace("www.","").replace( /#\w*/, "" );
#     current_link = current_link.replace("https://","").replace("http://","").replace("www.","");
#     isHomeMenu = 0;
#     if($("body").attr("id")=="index") isHomeMenu = 1;
#     $(".megamenu > li > a").each(function() {
#         menuURL = $(this).attr("href").replace("https://","").replace("http://","").replace("www.","").replace( /#\w*/, "" );
# 		if( (currentURL == menuURL) || (currentURL.replace(current_link,"") == menuURL) || isHomeMenu){
# 			$(this).parent().addClass("active");
#             return false;
# 		}
#     });
# // ]]>
# </script>
# <script type="text/javascript">
#     (function($) {
#         $.fn.OffCavasmenu = function(opts) {
#             // default configuration
#             var config = $.extend({}, {
#                 opt1: null,
#                 text_warning_select: "Please select One to remove?",
#                 text_confirm_remove: "Are you sure to remove footer row?",
#                 JSON: null
#             }, opts);
#             // main function
#             // initialize every element
#             this.each(function() {
#                 var $btn = $('#cavas_menu .navbar-toggle');
#                 var $nav = null;
#                 if (!$btn.length)
#                     return;
#                 var $nav = $('<section id="off-canvas-nav" class="leo-megamenu"><nav class="offcanvas-mainnav"><div id="off-canvas-button"><span class="off-canvas-nav"></span>Close</div></nav></section>');
#                 var $menucontent = $($btn.data('target')).find('.megamenu').clone();
#                 $("body").append($nav);
#                 $("#off-canvas-nav .offcanvas-mainnav").append($menucontent);
#                 $("#off-canvas-nav .offcanvas-mainnav").css('min-height',$(window).height()+30+"px");
#                 $("html").addClass ("off-canvas");
#                 $("#off-canvas-button").click( function(){
#                         $btn.click();
#                 } );
#                 $btn.toggle(function() {
#                     $("body").removeClass("off-canvas-inactive").addClass("off-canvas-active");
#                 }, function() {
#                     $("body").removeClass("off-canvas-active").addClass("off-canvas-inactive");
#                 });
#             });
#             return this;
#         }
#     })(jQuery);
#     $(document).ready(function() {
#         jQuery("#cavas_menu").OffCavasmenu();
#         $('#cavas_menu .navbar-toggle').click(function() {
#             $('body,html').animate({
#                 scrollTop: 0
#             }, 0);
# 			if ($('html').hasClass('fp-enabled')) {
# 				if ($('body').hasClass('off-canvas-active'))
# 				{
# 					$.fn.fullpage.pau();
# 				}
# 				else
# 				{
# 					$.fn.fullpage.con();
# 				};
# 			};
#             return false;
#         });
#     });
#     $(document.body).on('click', '[data-toggle="dropdown"]' ,function(){
#         if(!$(this).parent().hasClass('open') && this.href && this.href != '#'){
#             window.location.href = this.href;
#         }
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# <div id="pc_top">
# <div class="pc_cust" data-id="_">Customization:</div>
# <div class="pc_cart_container">
# <div class="pc_cart">
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# </section>
# </header>
# <div class="clearfix" id="breadcrumb">
# <div class="container">
# <!-- Breadcrumb -->
# <div class="breadcrumb clearfix aaa">
# <a class="home" href="https://www.misterchrono.com/" title="Return to Home">Home</a>
# <span &gt;="" class="navigation-pipe"></span>
# <span class="navigation_page">
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="https://www.misterchrono.com/en/126-watch-bookstore" itemprop="url" title="Watch Bookstore"><span itemprop="title">Watch Bookstore</span></a></span><span class="navigation-pipe">&gt;</span>Rolex  History, Icons and Record-Breaking Models
# 			</span>
# </div>
# <!-- /Breadcrumb -->
# </div>
# </div>
# <!-- Content -->
# <section class="columns-container" id="columns">
# <div class="container">
# <div class="row">
# <!-- Center -->
# <section class="col-md-12" id="center_column">
# <div itemscope="" itemtype="https://schema.org/Product">
# <meta content="https://www.misterchrono.com/en/watch-bookstore/4171-rolex-philosophy-3050262344227.html" itemprop="url"/>
# <div class="primary_block row">
# <div class="container">
# <div class="top-hr"></div>
# </div>
# <!-- left infos-->
# <div class="pb-left-column col-xs-12 col-sm-12 col-md-6">
# <!-- product img-->
# <div class="clearfix" id="image-block">
# <div class="p-label">
# <span class="label-new label label-info">New</span>
# </div>
# <span id="view_full_size">
# <img alt="CHRONOMASTER ONLY" class="img-responsive" id="bigpic" itemprop="image" src="https://www.misterchrono.com/14648-large_default/rolex-philosophy.jpg" title="CHRONOMASTER ONLY"/>
# <span class="span_link no-print status-enable btn btn-outline"></span>
# </span>
# </div> <!-- end image-block -->
# <!-- thumbnails -->
# <div class="clearfix hidden" id="views_block">
# <div id="thumbs_list">
# <ul id="thumbs_list_frame">
# <li class="last" id="thumbnail_14648">
# <a class="fancybox shown" data-fancybox-group="other-views" href="https://www.misterchrono.com/14648-thickbox_default/rolex-philosophy.jpg" title="CHRONOMASTER ONLY">
# <img alt="CHRONOMASTER ONLY" class="img-responsive" id="thumb_14648" itemprop="image" src="https://www.misterchrono.com/14648-cart_default/rolex-philosophy.jpg" title="CHRONOMASTER ONLY"/>
# </a>
# </li>
# </ul>
# </div> <!-- end thumbs_list -->
# </div> <!-- end views-block -->
# <!-- end thumbnails -->
# </div>
# <!-- end left infos-->
# <!-- center infos -->
# <div class="pb-center-column col-xs-12 col-sm-12 col-md-6">
# <h1 itemprop="name">Rolex  History, Icons and Record-Breaking Models</h1>
# <p id="product_reference">
# <label>Reference: </label>
# <span class="editable" content="WP - Rolex History" itemprop="sku">WP - Rolex History</span>
# </p>
# <p id="product_condition">
# <label>Condition: </label>
# <link href="https://schema.org/NewCondition" itemprop="itemCondition">
# <span class="editable">New product</span>
# </link></p>
# <div class="content_prices clearfix">
# <!-- prices -->
# <div class="price">
# <p class="our_price_display price-ttc" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer"><span content="38" id="our_price_display" itemprop="price">38,00 €</span><meta content="EUR" itemprop="priceCurrency"/></p>
# <p class="our_price_display price-ht" id="pretaxe_price">
# <span id="pretaxe_price_display" itemprop="price">
# 			31,67 €
# 			</span>
#
# 			Export price			</p>
# <p id="reduction_percent" style="display:none;"><span id="reduction_percent_display"></span></p>
# <p id="reduction_amount" style="display:none"><span id="reduction_amount_display"></span></p>
# <p class="hidden" id="old_price"><span id="old_price_display"></span></p>
# </div> <!-- end prices -->
# <div class="clear"></div>
# </div> <!-- end content_prices -->
# <div id="short_description_block">
# <div class="rte align_justify" id="short_description_content" itemprop="description"><p>Rolex</p>
# <p>History, Icons and Record-Breaking Models</p></div>
# </div> <!-- end short_description_block -->
# <!-- availability or doesntExist -->
# <p id="availability_statut" style="display: none;">
# <span class="label label-warning" id="availability_value"></span>
# </p>
# <p class="warning_inline" id="last_quantities" style="display: none">Warning: Last items in stock!</p>
# <p id="availability_date" style="display: none;">
# <span id="availability_date_label">Availability date:</span>
# <span id="availability_date_value"></span>
# </p>
# <!-- Out of stock hook -->
# <div id="oosHook">
# </div>
# <!-- usefull links-->
# <ul class="clearfix no-print" id="usefull_link_block">
# <li class="print">
# <a href="javascript:print();">
# 							Print
# 						</a>
# </li>
# </ul>
# </div>
# <!-- end center infos-->
# <!-- pb-right-column-->
# <div class="pb-right-column col-xs-12 col-sm-12 col-md-6 pull-right">
# <!-- add to cart form-->
# <form action="https://www.misterchrono.com/en/panier" id="buy_block" method="post">
# <!-- hidden datas -->
# <p class="hidden">
# <input name="token" type="hidden" value="2649f232fa66a36820c757455e61e85e"/>
# <input id="product_page_product_id" name="id_product" type="hidden" value="4171"/>
# <input name="add" type="hidden" value="1"/>
# <input id="idCombination" name="id_product_attribute" type="hidden" value=""/>
# </p>
# <div class="box-info-product">
# <div class="product_attributes clearfix">
# <!-- quantity wanted -->
# <div class="box-cart-wrapper">
# <p id="quantity_wanted_p">
# <label for="quantity_wanted">Quantity</label>
# <input class="text form-control" id="quantity_wanted" min="1" name="qty" type="number" value="1"/>
# <a class="btn btn-outline status-enable button-minus btn-sm product_quantity_down" data-field-qty="qty" href="#">
# <span><i class="fa fa-minus"></i></span>
# </a>
# <a class="btn btn-outline status-enable button-plus btn-sm product_quantity_up" data-field-qty="qty" href="#">
# <span><i class="fa fa-plus"></i></span>
# </a>
# <span class="clearfix"></span>
# </p>
# <div>
# <p class="buttons_bottom_block no-print" id="add_to_cart">
# <button class="exclusive btn btn-outline" name="Submit" type="submit">
# <span>Add to cart</span>
# </button>
# </p>
# </div>
# </div> <!-- end box cart wrapper-->
# <!-- minimal quantity wanted -->
# <p id="minimal_quantity_wanted_p" style="display: none;">
# 								The minimum purchase order quantity for the product is <b id="minimal_quantity_label">1</b>
# </p>
# </div> <!-- end product_attributes -->
# <div class="box-cart-bottom">
# <div class="box-inner">
# </div>
# </div> <!-- end box-cart-bottom -->
# </div>
# </form>
# <div class="box-social">
# <p class="socialsharing_product list-inline no-print">
# <button class="btn btn-outline btn-twitter social-sharing" data-type="twitter" type="button">
# <i class="fa fa-twitter"></i>  Tweet
# 				<!-- <img src="https://www.misterchrono.com/modules/socialsharing/img/twitter.gif" alt="Tweet" /> -->
# </button>
# <button class="btn btn-outline btn-facebook social-sharing" data-type="facebook" type="button">
# <i class="fa fa-facebook"></i> Share
# 				<!-- <img src="https://www.misterchrono.com/modules/socialsharing/img/facebook.gif" alt="Facebook Like" /> -->
# </button>
# <button class="btn btn-outline btn-google-plus social-sharing" data-type="google-plus" type="button">
# <i class="fa fa-google-plus"></i> Google+
# 				<!-- <img src="https://www.misterchrono.com/modules/socialsharing/img/google.gif" alt="Google Plus" /> -->
# </button>
# <button class="btn btn-outline btn-pinterest social-sharing" data-type="pinterest" type="button">
# <i class="fa fa-pinterest"></i>  Pinterest
# 				<!-- <img src="https://www.misterchrono.com/modules/socialsharing/img/pinterest.gif" alt="Pinterest" /> -->
# </button>
# </p>
# <div class="no-print" id="product_comments_block_extra" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating">
# <ul class="comments_advices">
# <li>
# <a class="open-comment-form" href="#new_comment_form">
# 					Write a review
# 				</a>
# </li>
# </ul>
# </div>
# <!--  /Module ProductComments -->
# </div>
# </div>
# <!-- end right infos-->
# </div>
# </div>
# <script type="text/javascript">
# $(document).ready(function(){
# 		$('.more_info_block .page-product-heading li:first, .more_info_block .tab-content section:first').addClass('active');
# 	});
# </script>
# <ul class="nav nav-tabs tab-info page-product-heading">
# <li class="active"><a data-toggle="tab" href="#tab2">More info</a></li>
# <li><a data-toggle="tab" href="#tab3">Data sheet</a></li>
# <li><a data-toggle="tab" href="#idTab5" id="link_idTab5">Reviews</a></li>
# </ul>
# <div class="tab-content">
# <!-- More info -->
# <section class="tab-pane page-product-box active" id="tab2">
# <!-- full description -->
# <div class="rte"><ul>
# <li>
# <p>The history of Rolex is inextricably linked to its founder Hans Wilsdorf, who took the first steps in the world of Swiss watchmaking as he dreamed about a timepiece that could be worn around the wrist. This experimental research led Rolex to achieve its highest goals in both technological innovation and in the use of the finest materials alone. Its models have been photographed on the wrists of political leaders, sports champions, and film and fashion celebrities, transforming each Rolex into a fully-fledged status symbol, a synonym of elegance and precision.</p>
# <p>Including essays with a historical and technical slant, in-depth descriptions of the most representative pieces and a brief glossary, the pages in this book sparkle with golden hands, diamond-studded dials and patent-leather watchbands, illustrated in period photographs and macro-detail. The volume ends with a chapter dedicated to the most amazing auctions that saw the sale of the Geneva-based company's vintage watches.</p>
# </li>
# </ul></div>
# </section>
# <!--end  More info -->
# <!-- Data sheet -->
# <section class="tab-pane page-product-box" id="tab3">
# <table class="table-data-sheet">
# <tr class="odd">
# <td>Language</td>
# <td>English</td>
# </tr>
# </table>
# </section>
# <!--end Data sheet -->
# <!--HOOK_PRODUCT_TAB -->
# <section class="tab-pane page-product-box" id="idTab5">
# <div id="product_comments_block_tab">
# <p class="align_center">
# <a class="btn btn-outline button button-small btn-sm open-comment-form" href="#new_comment_form" id="new_comment_tab_btn">
# <span>Be the first to write your review!</span>
# </a>
# </p>
# </div> <!-- #product_comments_block_tab -->
# </section>
# <!-- Fancybox -->
# <div style="display: none;">
# <div id="new_comment_form">
# <form action="#" id="id_new_comment_form">
# <h2 class="page-subheading">
# 				Write a review
# 			</h2>
# <div class="row">
# <div class="product clearfix col-xs-12 col-sm-6">
# <img alt="Rolex  History, Icons and Record-Breaking Models" height="125" src="https://www.misterchrono.com/14648-medium_default/rolex-philosophy.jpg" width="125"/>
# <div class="product_desc">
# <p class="product_name">
# <strong>Rolex  History, Icons and Record-Breaking Models</strong>
# </p>
# <p>Rolex</p>
# <p>History, Icons and Record-Breaking Models</p>
# </div>
# </div>
# <div class="new_comment_form_content col-xs-12 col-sm-6">
# <div class="error" id="new_comment_form_error" style="display: none; padding: 15px 25px">
# <ul></ul>
# </div>
# <ul id="criterions_list">
# <li>
# <label>Quality:</label>
# <div class="star_content">
# <input class="star not_uniform" name="criterion[1]" type="radio" value="1"/>
# <input class="star not_uniform" name="criterion[1]" type="radio" value="2"/>
# <input class="star not_uniform" name="criterion[1]" type="radio" value="3"/>
# <input checked="checked" class="star not_uniform" name="criterion[1]" type="radio" value="4"/>
# <input class="star not_uniform" name="criterion[1]" type="radio" value="5"/>
# </div>
# <div class="clearfix"></div>
# </li>
# </ul>
# <label for="comment_title">
# 						Title: <sup class="required">*</sup>
# </label>
# <input id="comment_title" name="title" type="text" value=""/>
# <label for="content">
# 						Comment: <sup class="required">*</sup>
# </label>
# <textarea id="content" name="content"></textarea>
# <label>
# 							Your name: <sup class="required">*</sup>
# </label>
# <input id="commentCustomerName" name="customer_name" type="text" value=""/>
# <div id="new_comment_form_footer">
# <input id="id_product_comment_send" name="id_product" type="hidden" value="4171"/>
# <p class="fl required"><sup>*</sup> Required fields</p>
# <p class="fr">
# <button class="btn button button-small btn-sm" id="submitNewMessage" name="submitMessage" type="submit">
# <span>Submit</span>
# </button>
# 							or
# 							<a class="closefb" href="#">
# 								Cancel
# 							</a>
# </p>
# <div class="clearfix"></div>
# </div> <!-- #new_comment_form_footer -->
# </div>
# </div>
# </form><!-- /end new_comment_form_content -->
# </div>
# </div>
# <!-- End fancybox -->
# <!--end HOOK_PRODUCT_TAB -->
# <!-- description & features -->
# </div>
# </section>
# </div>
# </div>
# </section>
# <!-- Footer -->
# <footer class="footer-container" id="footer">
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="footer-link container footer-block">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-4 col-lg-4 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGeneral -->
# <div class="ApHtml block">
# <h4 class="title_block">About our company</h4>
# <div class="toggle-footer"><p dir="ltr">The world of horology is a field that combines precision and patience.<br/>Passionate about this world and luxury watches, in 2009, four partners and friends decided to found a company that offers accessories related to high-end luxury watchmaking. This is the beginning of MisterChrono Paris.</p></div><p> </p>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-4 col-lg-4 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApBlockLink -->
# <div class="ApBlockLink" id="blockLink-form_9389890224009748">
# <div class="block">
# <h4 class="title_block">
# 					useful links
# 				</h4>
# <ul class="toggle-footer list-group bullet">
# <li><a href="https://www.misterchrono.com/en/content/46-histoire">About Us</a></li>
# <li><a href="https://www.misterchrono.com/en/content/37-conditions-generales-de-vente-en-ligne-">Privacy Policy</a></li>
# <li><a href="https://www.misterchrono.com/en/content/37-conditions-generales-de-vente-en-ligne-">Terms &amp; Conditions</a></li>
# <li><a href="https://www.misterchrono.com/en/content/40-nous-recrutons">Join Us</a></li>
# <li><a href="https://www.misterchrono.com/en/content/41-Join-the-MisterChrono-network-">Franchise</a></li>
# <li><a href="https://www.misterchrono.com/en/content/47-return-and-refund">return and refund</a></li>
# </ul>
# </div>
# </div>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-lg-4 col-md-4 col-sm-12 col-xs-12 col-sp-12 ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <!-- MODULE Block contact infos -->
# <div class="footer-block block" id="block_contact_infos">
# <div>
# <h4 class="title_block">Contact us</h4>
# <ul class="toggle-footer">
# <li class="local">
#             		MisterChrono Paris<br/>23 rue danielle casanova
# 75001 Paris            	</li>
# <li class="phone">
# <i class="fa fa-phone"></i>
# <span>09 53 42 04 64</span>
# </li>
# <li class="email">
# <i class="fa fa-envelope"></i>
# <span><a href="mailto:%63%6f%6e%74%61%63%74@%6d%69%73%74%65%72%63%68%72%6f%6e%6f.%63%6f%6d">contact@misterchrono.com</a></span>
# </li>
# </ul>
# </div>
# </div>
# <!-- /MODULE Block contact infos -->
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="footer-copyright">
# <div class="row ApRow has-bg bg-boxed" data-bg=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-md-12 col-lg-12 ApColumn">
# </div>
# </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\header -->
# <script type="text/javascript">
#         var leoOption = {
# 		productNumber:1,
# 		productInfo:0,
# 		productTran:1,
# 		productCdown: 1,
# 		productColor: 1,
# 		homeWidth: 250,
# 		homeheight: 250,
# 	}
#
#         $(document).ready(function(){
#             var leoCustomAjax = new $.LeoCustomAjax();
#             leoCustomAjax.processAjax();
#         });
# 	// Javascript code
# </script>
# </footer>
# </section><!-- #page -->
# <div id="back-top"><a class="fa fa-angle-up" href="#"></a></div>
# </body></html>

# %%
price = new_soup.find('span', attrs={"itemprop":"price"}).text

# %%
price
# Out:
# '38,00 €'

# %%
product_name = new_soup.find('h1', attrs={"itemprop":"name"}).text

# %%
product_name
# Out:
# 'Rolex  History, Icons and Record-Breaking Models'

# %%
product_availability = new_soup.find('span', attrs={"id":"availability_value"}).text

# %%
if product_availability == "":
    product_availability = 'na'
else:
    product_availability

# %%
product_availability
# Out:
# 'na'

# %% [markdown]
# #### CREATING FUNCTIONS TO BE REUSED WHENEVER RUNNING THE PROGRAM

# %% [markdown]
# ####     Define the functions which will help pull Product Name, Price and Availsbility of watches in www.misterchrono.com webstore

# %% [markdown]
# #### Since not always will we be able to find results,we instead replace with n/a, and whenever an AttributeError occurs we also replace with n/a instead

# %%
# Function to pull the Product Name
def get_product_name(soup):
    try:
        product_name = new_soup.find('h1', attrs={"itemprop":"name"}).text
    except AttributeError:
        product_name ='n/a'
        
    return product_name
        
# Function to pull the Product Price
def get_product_price(soup):
    try:
        product_price = new_soup.find('span', attrs={"itemprop":"price"}).text
    except AttributeError:
        product_price ='n/a'
        
    return product_price

# Function to pull the Product Availability
def get_product_availability(soup):
    try:
        product_availability= new_soup.find('span', attrs={"id":"availability_value"}).text
    except AttributeError:
        product_availability ='n/a'
        
    return product_availability

# %% [markdown]
# ### Writing the Universal script where

# %% [markdown]
# #### We define our url
# #### We request from the url access
# #### Get the links in to a list
# #### Iterate through the links using a for loop utilising the created functions so as to pick Product Name, Price and Availabilty
# #### Create a dictionary where the iterated link results get stored in
# #### Create a dataframe from the dictionary and drop every product name with NA, since it wont be of relevance not haveing product name
# #### Finally we store our data set in CSV file which can be later utilised for analysis and research.

# %%
if __name__ == '__main__':
    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.misterchrono.com/en/126-watch-bookstore"

    # HTTP Request
    page = requests.get(url, headers=Header)

    # Soup Object containing all data
    soup = bs(page.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all('a', attrs={'class':"product-name"})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"Name":[], "Price":[], "Availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_page = requests.get(link, headers=Header)

        new_soup = bs(new_page.content, "html.parser")

        # Function calls to display all necessary product information
        d['Name'].append(get_product_name(new_soup))
        d['Price'].append(get_product_price(new_soup))
        d['Availability'].append(get_product_availability(new_soup))

    
    watch_df = pd.DataFrame.from_dict(d)
    watch_df['Name'].replace('n/a', np.nan, inplace=True)
    watch_df = watch_df.dropna(subset=['Name'])
    watch_df.to_csv("watch_data.csv", header=True, index=False)

# %%
watch_df
# Out:
#                                                  Name     Price  \
# 0    Rolex  History, Icons and Record-Breaking Models   38,00 €
# 1                    Investing in wristwatches: Rolex   85,00 €
# 2           Patek Philippe: Investing in Wristwatches   95,00 €
# 3   Rolex Cosmograph Daytona  Vol. 1: Manual Windi...  175,00 €
# 4                                    Rolex Philosophy   65,00 €
# 5            Lexique Rolex – Gaspard SANDERS (French)   29,90 €
# 6                             Mondani - Vintage Patek  480,00 €
# 7   I IS FOR INDIE - ABCAIRES DES HORLOGERS INDEPE...   26,90 €
# 8   R IS FOR ROLEX - ABCDAIRE POUR LES FUTURES COL...   26,90 €
# 9                 THE WATCH COLLECTOR'S COLORING BOOK   26,90 €
# 10  Navitimer Story  The epic saga of the Breitlin...   49,00 €
# 11      Navitimer  L'épopée du chronographe Breitling   49,00 €
# 12                  Investir dans les montres : Rolex   89,00 €
# 13                             Rolex GMT-MASTER Story  620,00 €
# 14                      F.P.JOURNE - Invenit et Fecit  270,00 €
# 15                                  The Book of Rolex   44,00 €
# 16       Mondani - Patek Philippe Nautilus & Aquanaut  480,00 €
# 17             Mondani - Rolex Daytona Manual Winding  480,00 €
# 18                 Mondani-Rolex Daytona Self-Winding  480,00 €
# 19      Mondani-Rolex Submariner Sea-Dweller DeepSea   620,00 €
# 20  WATCHES An Identification Manual for Contempor...   49,00 €
# 21                            More than just the time   12,00 €
# 22                             Une montre sur la Lune   49,00 €
# 23                                 A Moon Watch Story   49,00 €
# 24         Flightmaster Only: The OMEGA pilot's watch  175,00 €
# 25                               The Magic Of Watches   40,00 €
# 26  L'annuel des montres 2015 - Catalogue raisonné...   53,55 €
# 27                 Trivial Pursuit - Fine Watchmaking   39,90 €
# 28                          Watches International XVI   65,42 €
# 29                                 Rolex Encyclopedia  680,00 €
# 30                                   Montres de sport   38,50 €
# 31  La Cote de montres modernes et de collection 2...   60,00 €
# 32  L'annuel des montres 2013: Catalogue raisonné ...   45,79 €
# 33                              La mécanique du geste   19,00 €
# 34                               Théorie d'horlogerie  179,00 €
# 35                           Montres de Judith Miller    9,95 €
#
#                           Availability
# 0
# 1                             in stock
# 2
# 3                             in stock
# 4                             in stock
# 5                             in stock
# 6                             in stock
# 7
# 8
# 9
# 10                            in stock
# 11                            in stock
# 12                            in stock
# 13
# 14                            in stock
# 15                            in stock
# 16
# 17                            in stock
# 18                            in stock
# 19                            in stock
# 20                            in stock
# 21                            in stock
# 22
# 23                            in stock
# 24  This product is no longer in stock
# 25                            in stock
# 26                            in stock
# 27                            In stock
# 28                            in stock
# 29                            in stock
# 30                            In stock
# 31                            in stock
# 32                            in stock
# 33                            in stock
# 34                            In stock
# 35                            In stock
